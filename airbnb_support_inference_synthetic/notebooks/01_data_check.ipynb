# %%
import pandas as pd

df = pd.read_csv("../data/mart_ticket_modeling.csv")

print(df.shape)
print(df.head())
print(df.columns.tolist())
# Out:
# (10000, 52)
#   ticket_id booking_id   issue_category contact_channel priority_initial  \
# 0   T000000    B000000  payment_problem           email             high
# 1   T000001    B000001  policy_question            chat           medium
# 2   T000002    B000002   refund_request            chat           medium
# 3   T000003    B000003   refund_request           phone              low
# 4   T000004    B000004  policy_question            chat              low
#
#   guest_id host_id listing_id  nights  days_until_checkin_at_ticket  ...  \
# 0   G00882  H00938     L02865       9                            12  ...
# 1   G01659  H00095     L00570       2                             2  ...
# 2   G03280  H00088     L01038       8                             4  ...
# 3   G03348  H01238     L00180       5                             7  ...
# 4   G03456  H00039     L00952       5                            28  ...
#
#    senior_agent_routing rebooking_coupon_offered repeat_contact_probability  \
# 0                     1                        0                      0.088
# 1                     1                        0                      0.223
# 2                     1                        0                      0.265
# 3                     0                        1                      0.492
# 4                     0                        0                      0.338
#
#    repeat_contact_7d  escalation_probability  escalated  resolution_hours  \
# 0                  0                   0.089          0              4.98
# 1                  0                   0.114          0              4.80
# 2                  0                   0.122          0             13.65
# 3                  1                   0.328          0             22.14
# 4                  0                   0.139          0              2.02
#
#    csat_score  poor_csat  long_resolution
# 0           5          0                0
# 1           5          0                0
# 2           5          0                0
# 3           4          0                0
# 4           4          0                0
#
# [5 rows x 52 columns]
# ['ticket_id', 'booking_id', 'issue_category', 'contact_channel', 'priority_initial', 'guest_id', 'host_id', 'listing_id', 'nights', 'days_until_checkin_at_ticket', 'total_booking_value', 'booking_status', 'cancelled_by', 'guest_account_age_days', 'guest_past_bookings_count', 'guest_past_support_tickets_12m', 'guest_past_refund_requests_12m', 'guest_lifetime_booking_value', 'guest_id_verified', 'host_superhost', 'host_response_rate', 'host_cancellation_rate_12m', 'host_avg_response_time_minutes', 'host_past_guest_complaints_12m', 'host_avg_rating', 'market', 'property_type', 'nightly_price', 'listing_review_score', 'listing_cleanliness_score', 'listing_accuracy_score', 'listing_review_count', 'cancellation_policy', 'instant_book_enabled', 'same_week_checkin_flag', 'strict_policy_flag', 'host_cancelled_booking_flag', 'high_value_booking_flag', 'sentiment_score', 'urgency_score', 'time_to_first_agent_response_minutes', 'message_count_first_30min', 'senior_agent_routing', 'rebooking_coupon_offered', 'repeat_contact_probability', 'repeat_contact_7d', 'escalation_probability', 'escalated', 'resolution_hours', 'csat_score', 'poor_csat', 'long_resolution']

# %%
import pandas as pd

df = pd.read_csv("../data/mart_ticket_modeling.csv")

target_summary = df[
    [
        "repeat_contact_7d",
        "escalated",
        "poor_csat",
        "long_resolution",
        "senior_agent_routing",
        "rebooking_coupon_offered"
    ]
].mean().sort_values(ascending=False)

print(target_summary)
# Out:
# repeat_contact_7d           0.3715
# senior_agent_routing        0.3224
# escalated                   0.2204
# rebooking_coupon_offered    0.1516
# long_resolution             0.1342
# poor_csat                   0.0255
# dtype: float64
